# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = 'AzviAB2XWJL8x6XvZC1B'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import os
import requests
import quandl
import collections
import json

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
data = quandl.get("FSE/AFX_X")
data
# Out:
#              Open   High    Low  Close  Change  Traded Volume     Turnover  \
# Date
# 2000-06-07    NaN    NaN    NaN  38.00     NaN            0.0          NaN
# 2000-06-08    NaN    NaN    NaN  38.00     NaN            0.0          NaN
# 2000-06-09    NaN    NaN    NaN  45.00     NaN            0.0          NaN
# 2000-06-12    NaN    NaN    NaN  45.00     NaN            0.0          NaN
# 2000-06-13    NaN    NaN    NaN  45.00     NaN            0.0          NaN
# 2000-06-14    NaN    NaN    NaN  45.00     NaN            0.0          NaN
# 2000-06-15    NaN    NaN    NaN  39.64     NaN            0.0          NaN
# 2000-06-16    NaN    NaN    NaN  39.64     NaN            0.0          NaN
# 2000-06-19    NaN    NaN    NaN  39.64     NaN            0.0          NaN
# 2000-06-20    NaN    NaN    NaN  39.64     NaN            0.0          NaN
# 2000-06-21    NaN    NaN    NaN  39.64     NaN            0.0          NaN
# 2000-06-22    NaN    NaN    NaN  39.51     NaN            0.0          NaN
# 2000-06-23    NaN    NaN    NaN  39.51     NaN            0.0          NaN
# 2000-06-26    NaN    NaN    NaN  39.51     NaN            0.0          NaN
# 2000-06-27    NaN    NaN    NaN  39.51     NaN            0.0          NaN
# 2000-06-28    NaN    NaN    NaN  39.51     NaN            0.0          NaN
# 2000-06-29    NaN    NaN    NaN  39.51     NaN            0.0          NaN
# 2000-06-30    NaN    NaN    NaN  39.51     NaN            0.0          NaN
# 2000-07-03    NaN    NaN    NaN  39.51     NaN            0.0          NaN
# 2000-07-04    NaN    NaN    NaN  39.65     NaN            0.0          NaN
# 2000-07-05    NaN    NaN    NaN  40.50     NaN            0.0          NaN
# 2000-06-19                  None               None             0.0
# 2000-06-20                  None               None             0.0
# 2000-06-21                  None               None             0.0
# 2000-06-22                  None               None             0.0
# 2000-06-23                  None               None             0.0
# 2000-06-26                  None               None             0.0
# 2000-06-27                  None               None             0.0
# 2000-06-28                  None               None             0.0
# 2000-06-29                  None               None             0.0
# 2000-06-30                  None               None             0.0
# 2000-07-03                  None               None             0.0
# 2000-07-04                  None               None             0.0
# 2000-07-05                  None               None             0.0
# 2000-07-06                  None               None             0.0
# 2000-07-07                  None               None             0.0
# 2000-07-10                  None               None             0.0
# 2000-07-11                  None               None             0.0
# 2000-07-12                  None               None             0.0
# 2000-07-13                  None               None             0.0
# 2000-07-14                  None               None             0.0
# 2000-07-17                  None               None             0.0
# 2000-07-18                  None               None             0.0
# ...                          ...                ...             ...
# 2020-04-17                  None               None             NaN
# 2020-04-20                  None               None             NaN
# 2020-04-21                  None               None             NaN
# 2020-04-22                  None               None             NaN
# 2020-04-23                  None               None             NaN
# 2020-04-24                  None               None             NaN
# 2020-04-27                  None               None             NaN
# 2020-04-28                  None               None             NaN
# 2020-04-29                  None               None             NaN
# 2020-04-30                  None               None             NaN
# 2020-05-04                  None               None             NaN
# 2020-05-05                  None               None             NaN
# 2020-05-06                  None               None             NaN
# 2020-05-07                  None               None             NaN
# 2020-05-08                  None               None             NaN
# 2020-05-11                  None               None             NaN
# 2020-05-12                  None               None             NaN
# 2020-05-13                  None               None             NaN
# 2020-05-14                  None               None             NaN
# 2020-05-15                  None               None             NaN
# 2020-05-18                  None               None             NaN
# 2020-05-19                  None               None             NaN
# 2020-05-20                  None               None             NaN
# 2020-05-21                  None               None             NaN
# 2020-05-22                  None               None             NaN
# 2020-05-25                  None               None             NaN
# 2020-05-26                  None               None             NaN
# 2020-05-27                  None               None             NaN
# 2020-05-28                  None               None             NaN
# 2020-05-29                  None               None             NaN
#
# [5137 rows x 10 columns]

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %% [markdown]
# 2:

# %%
data_dict = data.T.to_dict()
#print(data_dict)

# %% [markdown]
# 3:

# %%
info = []
for key in data_dict.keys():
    if key.year == 2017:
        info.append([data_dict[key]['Open'],data_dict[key]['Close'],data_dict[key]['High'],data_dict[key]['Low'],data_dict[key]['Traded Volume']])
print('Highest opening price: $'+str(max(info)[0]))
print('Lowest opening price: $'+str(min(info)[0]))
# Out:
# Highest opening price: $53.11
# Lowest opening price: $34.0

# %% [markdown]
# 4:

# %%
changes1 = []
for entry in info:
    changes1.append(entry[2]-entry[3])
print('Largest change in any one day based on High and Low price: $'+str(round(max(changes1),2)))
# Out:
# Largest change in any one day based on High and Low price: $2.81

# %% [markdown]
# 5:

# %%
changes2 = []
for i in range(1,len(info)):
    changes2.append(info[i][1]-info[i-1][1])
print('Largest change in any one day based on Closing Price: $'+str(round(max(changes2),2)))
# Out:
# Largest change in any one day based on Closing Price: $1.72

# %% [markdown]
# 6:

# %%
total_vol = 0
for entry in info:
    total_vol += entry[4]
avg_vol = total_vol/len(info)

print('Average daily trading volume: '+str(round(avg_vol,4)))
# Out:
# Average daily trading volume: 89124.3373
